# %%
import pandas as pd
import openpyxl

# %%
data = pd.read_excel("2019_travel_card.xls")

# %%
data
# Out:
#            사용월      노선ID  노선번호                노선명  버스정류장ID      버스정류장명  승차승객수  \
# 0      2019-10  11110897  0017     0017번(청암동~이촌동)  8501292     청암자이아파트    670
# 1      2019-10  11110897  0017     0017번(청암동~이촌동)  9003185  청암동강변삼성아파트  1,986
# 2      2019-10  11110897  0017     0017번(청암동~이촌동)    72983       청심경로당  3,144
# 3      2019-10  11110897  0017     0017번(청암동~이촌동)    72984    원효2동주민센터  5,809
# 4      2019-10  11110897  0017     0017번(청암동~이촌동)    72985         산천동  7,665
# ...        ...       ...   ...                ...      ...         ...    ...
# 38807  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008325       면목지구대  4,282
# 38808  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011767       새마을금고  1,031
# 38809  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008323         공판장     62
# 38810  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011768   진주빌라.바다약국     43
# 38811  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011765   진로아파트앞.종점    951
#
# ...

# %%
# csv 파일로 저장
data.to_csv('2019_10_bus_data.csv')

# %%
# 저장한 csv파일 읽기
bus = pd.read_csv('2019_10_bus_data.csv')

# %%
bus
# Out:
#        Unnamed: 0      사용월      노선ID  노선번호                노선명  버스정류장ID  \
# 0               0  2019-10  11110897  0017     0017번(청암동~이촌동)  8501292
# 1               1  2019-10  11110897  0017     0017번(청암동~이촌동)  9003185
# 2               2  2019-10  11110897  0017     0017번(청암동~이촌동)    72983
# 3               3  2019-10  11110897  0017     0017번(청암동~이촌동)    72984
# 4               4  2019-10  11110897  0017     0017번(청암동~이촌동)    72985
# ...           ...      ...       ...   ...                ...      ...
# 38807       38807  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008325
# 38808       38808  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011767
# 38809       38809  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008323
# 38810       38810  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011768
# 38811       38811  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011765
#
#            버스정류장명  승차승객수   하차승객수                 작업일시
# 0         청암자이아파트    670      16  2019-11-03 11:55:38
# ...

# %%
# 인덱스 번호 없이 csv파일 만들기
data.to_csv('2019_10_bus_data_unnamed.csv', index = None)

# %%
bus = pd.read_csv('2019_10_bus_data_unnamed.csv')
bus
# Out:
#            사용월      노선ID  노선번호                노선명  버스정류장ID      버스정류장명  승차승객수  \
# 0      2019-10  11110897  0017     0017번(청암동~이촌동)  8501292     청암자이아파트    670
# 1      2019-10  11110897  0017     0017번(청암동~이촌동)  9003185  청암동강변삼성아파트  1,986
# 2      2019-10  11110897  0017     0017번(청암동~이촌동)    72983       청심경로당  3,144
# 3      2019-10  11110897  0017     0017번(청암동~이촌동)    72984    원효2동주민센터  5,809
# 4      2019-10  11110897  0017     0017번(청암동~이촌동)    72985         산천동  7,665
# ...        ...       ...   ...                ...      ...         ...    ...
# 38807  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008325       면목지구대  4,282
# 38808  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011767       새마을금고  1,031
# 38809  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008323         공판장     62
# 38810  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011768   진주빌라.바다약국     43
# 38811  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011765   진로아파트앞.종점    951
#
# ...

# %%
# csv to excel
bus.to_excel('2019_10_bus_data.xlsx',index=None)

# %%
bus = pd.read_excel('2019_10_bus_data.xlsx')
bus
# Out:
#            사용월      노선ID  노선번호                노선명  버스정류장ID      버스정류장명  승차승객수  \
# 0      2019-10  11110897  0017     0017번(청암동~이촌동)  8501292     청암자이아파트    670
# 1      2019-10  11110897  0017     0017번(청암동~이촌동)  9003185  청암동강변삼성아파트  1,986
# 2      2019-10  11110897  0017     0017번(청암동~이촌동)    72983       청심경로당  3,144
# 3      2019-10  11110897  0017     0017번(청암동~이촌동)    72984    원효2동주민센터  5,809
# 4      2019-10  11110897  0017     0017번(청암동~이촌동)    72985         산천동  7,665
# ...        ...       ...   ...                ...      ...         ...    ...
# 38807  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008325       면목지구대  4,282
# 38808  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011767       새마을금고  1,031
# 38809  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008323         공판장     62
# 38810  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011768   진주빌라.바다약국     43
# 38811  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011765   진로아파트앞.종점    951
#
# ...

# %%
# 탭으로 분리된 파일 만들기
bus.to_csv('2019_10_bus_data.tsv', sep = '\t', index = None)
bus = pd.read_csv('2019_10_bus_data.tsv', sep ='\t')
bus
# Out:
#            사용월      노선ID  노선번호                노선명  버스정류장ID      버스정류장명  승차승객수  \
# 0      2019-10  11110897  0017     0017번(청암동~이촌동)  8501292     청암자이아파트    670
# 1      2019-10  11110897  0017     0017번(청암동~이촌동)  9003185  청암동강변삼성아파트  1,986
# 2      2019-10  11110897  0017     0017번(청암동~이촌동)    72983       청심경로당  3,144
# 3      2019-10  11110897  0017     0017번(청암동~이촌동)    72984    원효2동주민센터  5,809
# 4      2019-10  11110897  0017     0017번(청암동~이촌동)    72985         산천동  7,665
# ...        ...       ...   ...                ...      ...         ...    ...
# 38807  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008325       면목지구대  4,282
# 38808  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011767       새마을금고  1,031
# 38809  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9008323         공판장     62
# 38810  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011768   진주빌라.바다약국     43
# 38811  2019-10  11110729  중랑02  중랑02(진로아파트~한신아파트)  9011765   진로아파트앞.종점    951
#
# ...
